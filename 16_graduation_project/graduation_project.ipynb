# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-чтение-данных" data-toc-modified-id="Загрузка-и-чтение-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка и чтение данных</a></span><ul class="toc-item"><li><span><a href="#Датасет-&quot;contract&quot;" data-toc-modified-id="Датасет-&quot;contract&quot;-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Датасет "contract"</a></span></li><li><span><a href="#Датасет-&quot;personal&quot;" data-toc-modified-id="Датасет-&quot;personal&quot;-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Датасет "personal"</a></span></li><li><span><a href="#Датасет-&quot;internet&quot;" data-toc-modified-id="Датасет-&quot;internet&quot;-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Датасет "internet"</a></span></li><li><span><a href="#Датасет-&quot;phone&quot;" data-toc-modified-id="Датасет-&quot;phone&quot;-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Датасет "phone"</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Датасет-&quot;contract&quot;" data-toc-modified-id="Датасет-&quot;contract&quot;-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Датасет "contract"</a></span></li><li><span><a href="#Датасет-&quot;personal&quot;" data-toc-modified-id="Датасет-&quot;personal&quot;-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Датасет "personal"</a></span></li><li><span><a href="#Датасет-&quot;internet&quot;" data-toc-modified-id="Датасет-&quot;internet&quot;-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Датасет "internet"</a></span></li><li><span><a href="#Датасет-&quot;phone&quot;" data-toc-modified-id="Датасет-&quot;phone&quot;-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Датасет "phone"</a></span></li></ul></li><li><span><a href="#Вывод-по-разделу-&quot;Исследовательский-анализ-данных&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Исследовательский-анализ-данных&quot;-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод по разделу "Исследовательский анализ данных"</a></span></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Вопросы-тимлиду" data-toc-modified-id="Вопросы-тимлиду-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вопросы тимлиду</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Объединение-данных-в-одну-таблицу" data-toc-modified-id="Объединение-данных-в-одну-таблицу-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Объединение данных в одну таблицу</a></span></li><li><span><a href="#Преобразование-категориальных-признаков" data-toc-modified-id="Преобразование-категориальных-признаков-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Преобразование категориальных признаков</a></span></li><li><span><a href="#Разбивка-данных-на-выборки" data-toc-modified-id="Разбивка-данных-на-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Разбивка данных на выборки</a></span></li><li><span><a href="#Масштабирование-признаков" data-toc-modified-id="Масштабирование-признаков-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Масштабирование признаков</a></span></li><li><span><a href="#Вывод-по-разделу-&quot;Предобработка-данных&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Предобработка-данных&quot;-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод по разделу "Предобработка данных"</a></span></li></ul></li><li><span><a href="#Подбор-и-обучение-моделей" data-toc-modified-id="Подбор-и-обучение-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подбор и обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Модель-LogisticRegression" data-toc-modified-id="Модель-LogisticRegression-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Модель LogisticRegression</a></span></li><li><span><a href="#Модель-RandomForestClassifier" data-toc-modified-id="Модель-RandomForestClassifier-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Модель RandomForestClassifier</a></span></li><li><span><a href="#Модель-DecisionTreeClassifier" data-toc-modified-id="Модель-DecisionTreeClassifier-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Модель DecisionTreeClassifier</a></span></li><li><span><a href="#Модель-CatBoostClassifier" data-toc-modified-id="Модель-CatBoostClassifier-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Модель CatBoostClassifier</a></span></li><li><span><a href="#Модель-XGBClassifier" data-toc-modified-id="Модель-XGBClassifier-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Модель XGBClassifier</a></span></li><li><span><a href="#Модель-LGBMClassifier" data-toc-modified-id="Модель-LGBMClassifier-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Модель LGBMClassifier</a></span></li><li><span><a href="#Сводная-таблица-с-результатами" data-toc-modified-id="Сводная-таблица-с-результатами-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Сводная таблица с результатами</a></span></li><li><span><a href="#Вывод-по-разделу-&quot;Подбор-и-обучение-моделей&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Подбор-и-обучение-моделей&quot;-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Вывод по разделу "Подбор и обучение моделей"</a></span></li></ul></li><li><span><a href="#Проверка-данных-на-тестовой-выборке" data-toc-modified-id="Проверка-данных-на-тестовой-выборке-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка данных на тестовой выборке</a></span><ul class="toc-item"><li><span><a href="#Проверка-моделей-на-тестовой-выборке" data-toc-modified-id="Проверка-моделей-на-тестовой-выборке-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проверка моделей на тестовой выборке</a></span></li><li><span><a href="#Сравнение-выбранной-модели-с-константной" data-toc-modified-id="Сравнение-выбранной-модели-с-константной-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Сравнение выбранной модели с константной</a></span></li><li><span><a href="#Сводная-таблица-с-результатами" data-toc-modified-id="Сводная-таблица-с-результатами-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Сводная таблица с результатами</a></span></li><li><span><a href="#Вывод-по-разделу-&quot;Проверка-данных-на-тестовой-выборке&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Проверка-данных-на-тестовой-выборке&quot;-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Вывод по разделу "Проверка данных на тестовой выборке"</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Телеком — выпускной проект

# %% [markdown]
# ## Введение

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# **Описание услуг**
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# - Выделенная линия технической поддержки (*TechSupport*);
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# **Описание данных**
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract.csv` — информация о договоре;
# - `personal.csv` — персональные данные клиента;
# - `internet.csv` — информация об интернет-услугах;
# - `phone.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.
#
# Целевой признак: столбец 'EndDate' равен 'No'.

# %% [markdown]
# **Данные**
#
# [final_provider.zip](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/ac39c23b-718e-4cd6-bdaa-85b3a127a457/final_provider.zip)
#
# Данные также находятся в тренажёре, в папке `/datasets/final_provider/`.

# %% [markdown]
# **Этапы выполнения проекта:**
#
# 1. Составьте план работы. Исходное условие задачи заведомо неполное и содержит лишнюю информацию. Проведите исследовательский анализ данных, чтобы понять, какие вопросы подготовить.
# 2. Уточните задачу. Задайте вопросы тимлиду.
# 3. Разработайте модель. Отдайте код на проверку ревьюверу.
# 4. Подготовьте отчёт. Отправьте отчёт тимлиду, чтобы он проверил успешность выполнения задания.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.dummy import DummyClassifier

# %% [markdown]
# ### Загрузка и чтение данных

# %% [markdown]
# #### Датасет "contract"

# %%
contract = pd.read_csv('/datasets/final_provider/contract.csv')

# %% [markdown]
# Напишем функцию для вывода на экран основной информации о датасете: отображение первых 10 строк, общая и статистическая информация, проверка количества дубликатов.

# %%
def dataset_info(df):
    print(df.head(10))
    print(' ')
    print ('\033[1m' + 'Вывод метода info():' + '\033[0m')
    print(df.info())
    print(' ')
    print ('\033[1m' + 'Вывод метода isna():' + '\033[0m')
    print('Количество пропущенных значений:')
    print(df.isna().sum())
    print(' ')
    print ('\033[1m' + 'Вывод метода duplicated():' + '\033[0m')
    print('Количество дубликатов:', df.duplicated().sum())

# %%
dataset_info(contract)
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# 5  9305-CDSKC  2019-03-01  2019-11-01 00:00:00  Month-to-month
# 6  1452-KIOVK  2018-04-01                   No  Month-to-month
# 7  6713-OKOMC  2019-04-01                   No  Month-to-month
# 8  7892-POOKP  2017-07-01  2019-11-01 00:00:00  Month-to-month
# 9  6388-TABGU  2014-12-01                   No        One year
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# ...

# %% [markdown]
# Датасет **contract** состоит из 8 столбцов (признаков) и 7043 записей (объектов):
#
# Каждая строка таблицы содержит информацию о договорах клиентов с оператором связи.
#
# **Признаки:**
# <li>customerID - уникальный идентификатор клиента;</li>
# <li>BeginDate - дата заключения договора;</li>
# <li>EndDate - дата окончания (закрытия) договора;</li>
# <li>Type - тип договора (вероятно, имеется ввиду пролонгация договора: помесячно, на год);</li>
# <li>PaperlessBilling - выставление счета в электронной форме;</li>
# <li>PaymentMethod - способ оплаты;</li>
# <li>MonthlyCharges - ежемесячный платеж;</li>
# <li>TotalCharges - платежи за весь период действия договора.</li>
#
# При первичном анализе выявлены следующие особенности:
# 1. Наименования столбцов датафрейма не приведены к нижнему регистру;
# 2. Признаки с датой **BeginDate** и **EndDate** имеют тип данных `object` - необходимо привести к типу `datetime`;
# 3. Числовой признак **TotalCharges** имеет тип данных `object` - необходимо привести к числовому формату `float64`;
# 4. Значения бинарного признака **PaperlessBilling** представить в виде 0 ('No') и 1 ('Yes');
# 5. По дате открытия и закрытия договора, либо по дате открытия и дате сбора информации (1 февраля 2020 года) можно определить продолжительность сотрудничества клиента и оператора связи;
# 6. Признаки в столбцах в столбцах **Type**, **PaperlessBilling**, **PaymentMethod** - категориальные, в столбцах **MonthlyCharges**, **TotalCharges** - количественные.
#
# Пропущенные значения и дубликаты в датасете отсутствуют.

# %% [markdown]
# #### Датасет "personal"

# %%
personal = pd.read_csv('/datasets/final_provider/personal.csv')

# %%
dataset_info(personal)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes
#
# Вывод метода info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
# customerID       7043 non-null object
# gender           7043 non-null object
# SeniorCitizen    7043 non-null int64
# Partner          7043 non-null object
# Dependents       7043 non-null object
# ...

# %%
personal['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# Датасет **personal** состоит из 5 столбцов (признаков) и 7043 записей (объектов):
#
# Каждая строка таблицы содержит информацию о персональных данных клиентов.
#
# **Признаки:**
# <li>customerID - уникальный идентификатор клиента;</li>
# <li>gender - пол клиента;</li>
# <li>SeniorCitizen - является ли книент пенсионером;</li>
# <li>Partner - наличие партнера, семейное положение;</li>
# <li>Dependents - наличие иждивенцев, детей.</li>
#
# При первичном анализе выявлены следующие особенности:
# 1. Количество объектов соответствует количеству объектов датасета **contract**;
# 2. Наименования столбцов датафрейма не приведены к нижнему регистру (кроме 'gender');
# 3. Типы данных имеют корректный вид;
# 4. Значения бинарных признаков **Partner** и **Dependents** представить в виде 0 ('No') и 1 ('Yes');
# 5. Все признаки - категориальные.
#
# Пропущенные значения и дубликаты в датасете отсутствуют.

# %% [markdown]
# #### Датасет "internet"

# %%
internet = pd.read_csv('/datasets/final_provider/internet.csv')

# %%
dataset_info(internet)
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
# 5  9305-CDSKC     Fiber optic             No           No              Yes
# 6  1452-KIOVK     Fiber optic             No          Yes               No
# 7  6713-OKOMC             DSL            Yes           No               No
# 8  7892-POOKP     Fiber optic             No           No              Yes
# 9  6388-TABGU             DSL            Yes          Yes               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# ...

# %% [markdown]
# Датасет **internet** состоит из 8 столбцов (признаков) и 5517 записей (объектов):
#
# Каждая строка таблицы содержит информацию о доступных интернет-услугах оператора связи, используемых клиентом.
#
# **Признаки:**
# <li>customerID - уникальный идентификатор клиента;</li>
# <li>InternetService - технология связи: телефонная линия (DSL), оптоволокно (Fiber optic);</li>
# <li>OnlineSecurity - блокировщик небезопасных сайтов;</li>
# <li>OnlineBackup - резервное копирование в облачное хранилище;</li>
# <li>DeviceProtection - антивирус;</li>
# <li>TechSupport - наличие тех. поддержки;</li>
# <li>StreamingTV - стриминговое ТВ;</li>
# <li>StreamingMovies - сервис просмотра фильмов.</li>
#
# При первичном анализе выявлены следующие особенности:
# 1. Наименования столбцов датафрейма не приведены к нижнему регистру;
# 2. Типы данных имеют корректный вид;
# 2. Значения бинарных признаков представить в виде 0 ('No') и 1 ('Yes');
# 3. Все признаки - категориальные.
#
# Пропущенные значения и дубликаты в датасете отсутствуют.

# %% [markdown]
# #### Датасет "phone"

# %%
phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %%
dataset_info(phone)
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# 5  7892-POOKP           Yes
# 6  6388-TABGU            No
# 7  9763-GRSKD            No
# 8  7469-LKBCI            No
# 9  8091-TTVAX           Yes
#
# Вывод метода info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
# customerID       6361 non-null object
# MultipleLines    6361 non-null object
# dtypes: object(2)
# memory usage: 99.5+ KB
# None
#
# Вывод метода isna():
# Количество пропущенных значений:
# customerID       0
# MultipleLines    0
# dtype: int64
#
# Вывод метода duplicated():
# Количество дубликатов: 0

# %% [markdown]
# Датасет **phone** состоит из 2 столбцов (признаков) и 6361 записи (объекта):
#
# Каждая строка таблицы содержит информацию об услугах телефонии, используемых клиентом.
#
# **Признаки:**
# <li>customerID - уникальный идентификатор клиента;</li>
# <li>MultipleLines - подключение аппарата к нескольким линиям.</li>
#
# При первичном анализе выявлены следующие особенности:
# 1. Типы данных имеют корректный вид;
# 2. Значения бинарных признаков **MultipleLines** представить в виде 0 ('No') и 1 ('Yes');
# 3. Единственный признак - категориальный.
#
# Пропущенные значения и дубликаты в датасете отсутствуют.

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# #### Датасет "contract"

# %% [markdown]
# Приведем наименования столбцов датасета к нижнему регистру:

# %%
contract.set_axis(['customer_id', 'begin_date', 'end_date', 'type', 'paperless_billing', 
                              'payment_method', 'monthly_charges', 'total_charges'], axis=1, inplace=True)

# %%
contract.head(3)
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
#
#   paperless_billing    payment_method  monthly_charges total_charges
# 0               Yes  Electronic check            29.85         29.85
# 1                No      Mailed check            56.95        1889.5
# 2               Yes      Mailed check            53.85        108.15

# %% [markdown]
# **Целевой признак**

# %% [markdown]
# Мы знаем, что столбец **end_date** содержит целевой признак. Т.к. нам нужно определить отток клиентов оператора, то закрытие контракта означает уход клиента. Добавим к датасету столбец **churn** с целдевым признаком, где закрытие контракта обозначим цифрой "1", а значение "No" цифрой "0":

# %%
contract.loc[(contract['end_date'] == 'No'), 'churn'] = 0
contract.loc[(contract['end_date'] != 'No'), 'churn'] = 1

# %%
contract['churn'] = contract['churn'].astype('int')

# %%
contract.head(10)
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# 5  9305-CDSKC  2019-03-01  2019-11-01 00:00:00  Month-to-month
# 6  1452-KIOVK  2018-04-01                   No  Month-to-month
# 7  6713-OKOMC  2019-04-01                   No  Month-to-month
# 8  7892-POOKP  2017-07-01  2019-11-01 00:00:00  Month-to-month
# 9  6388-TABGU  2014-12-01                   No        One year
#
#   paperless_billing             payment_method  monthly_charges total_charges  \
# 0               Yes           Electronic check            29.85         29.85
# 1                No               Mailed check            56.95        1889.5
# ...

# %% [markdown]
# Также, приведем столбцы **begin_date** и **end_date** к типу `datetime64`:

# %%
contract['begin_date'] = pd.to_datetime(contract['begin_date'], format='%Y-%m-%d')

# %% [markdown]
# Нам известно, что если клиент не ушел из компании по состоянию на 1 февраля 2020 года, то он продолжает пользоваться услугами оператора связи. Заменим в столбце **end_date** значение "No" на дату "2020-02-01":

# %%
contract.loc[(contract['end_date'] == 'No'), 'end_date'] = '2020-02-01'

# %% [markdown]
# И приведем значения в столбце **end_date** к формату `datetime64`:

# %%
contract['end_date'] = pd.to_datetime(contract['end_date'], format='%Y-%m-%d')

# %% [markdown]
# Также приведем значения в столбце **total_charges** к вещественному типу `float64`:

# %%
contract['total_charges'] = pd.to_numeric(contract['total_charges'], errors='coerce')

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
# customer_id          7043 non-null object
# begin_date           7043 non-null datetime64[ns]
# end_date             7043 non-null datetime64[ns]
# type                 7043 non-null object
# paperless_billing    7043 non-null object
# payment_method       7043 non-null object
# monthly_charges      7043 non-null float64
# total_charges        7032 non-null float64
# churn                7043 non-null int64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 495.3+ KB

# %% [markdown]
# В столбце **total_charges** обнаружилось 11 пропущенных значений, посмотрим на них:

# %%
contract.sort_values(by='total_charges').tail(11)
# Out:
#      customer_id begin_date   end_date      type paperless_billing  \
# 488   4472-LVYGI 2020-02-01 2020-02-01  Two year               Yes
# 753   3115-CZMZD 2020-02-01 2020-02-01  Two year                No
# 936   5709-LVOEQ 2020-02-01 2020-02-01  Two year                No
# 1082  4367-NUYAO 2020-02-01 2020-02-01  Two year                No
# 1340  1371-DWPAZ 2020-02-01 2020-02-01  Two year                No
# 3331  7644-OMVMY 2020-02-01 2020-02-01  Two year                No
# 3826  3213-VVOLG 2020-02-01 2020-02-01  Two year                No
# 4380  2520-SGTTA 2020-02-01 2020-02-01  Two year                No
# 5218  2923-ARZLG 2020-02-01 2020-02-01  One year               Yes
# 6670  4075-WKNIU 2020-02-01 2020-02-01  Two year                No
# 6754  2775-SEFEE 2020-02-01 2020-02-01  Two year               Yes
#
#                  payment_method  monthly_charges  total_charges  churn
# 488   Bank transfer (automatic)            52.55            NaN      0
# ...

# %% [markdown]
# Эти клиенты недавно подключились и их оплата еще не была включена в итоговую. Заменим значения с пропусками на значения столбца "monthly_charges":

# %%
NaN = contract.sort_values(by='total_charges').tail(11)['total_charges'].index

# %%
contract['total_charges'] = np.where(contract['total_charges'] > 0, \
                                       contract['total_charges'], contract['monthly_charges'])

# %%
contract.loc[NaN]
# Out:
#      customer_id begin_date   end_date      type paperless_billing  \
# 488   4472-LVYGI 2020-02-01 2020-02-01  Two year               Yes
# 753   3115-CZMZD 2020-02-01 2020-02-01  Two year                No
# 936   5709-LVOEQ 2020-02-01 2020-02-01  Two year                No
# 1082  4367-NUYAO 2020-02-01 2020-02-01  Two year                No
# 1340  1371-DWPAZ 2020-02-01 2020-02-01  Two year                No
# 3331  7644-OMVMY 2020-02-01 2020-02-01  Two year                No
# 3826  3213-VVOLG 2020-02-01 2020-02-01  Two year                No
# 4380  2520-SGTTA 2020-02-01 2020-02-01  Two year                No
# 5218  2923-ARZLG 2020-02-01 2020-02-01  One year               Yes
# 6670  4075-WKNIU 2020-02-01 2020-02-01  Two year                No
# 6754  2775-SEFEE 2020-02-01 2020-02-01  Two year               Yes
#
#                  payment_method  monthly_charges  total_charges  churn
# 488   Bank transfer (automatic)            52.55          52.55      0
# ...

# %% [markdown]
# Зная дату заключения и расторжения договора можно определить сколько времени (дней) клиент пользовался услугами оператора:

# %%
contract['contract_time'] = (contract['end_date'] - contract['begin_date']).astype('timedelta64[D]')

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
# customer_id          7043 non-null object
# begin_date           7043 non-null datetime64[ns]
# end_date             7043 non-null datetime64[ns]
# type                 7043 non-null object
# paperless_billing    7043 non-null object
# payment_method       7043 non-null object
# monthly_charges      7043 non-null float64
# total_charges        7043 non-null float64
# churn                7043 non-null int64
# contract_time        7043 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(4)
# memory usage: 550.4+ KB

# %% [markdown]
# Количество месяцев действия контракта представим в целочисленном виде:

# %%
contract['contract_time'] = contract['contract_time'].astype('int')

# %%
contract.head(5)
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year                No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year                No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  churn  \
# 0           Electronic check            29.85          29.85      0
# 1               Mailed check            56.95        1889.50      0
# 2               Mailed check            53.85         108.15      1
# 3  Bank transfer (automatic)            42.30        1840.75      0
# 4           Electronic check            70.70         151.65      1
#
#    contract_time
# 0             31
# 1           1036
# 2             61
# 3           1371
# 4             61

# %% [markdown]
# **Распределение категориальных признаков**

# %% [markdown]
# Посмотрим на распределение категориальных признаков в столбцах **type**, **paperless_billing**, **payment_method** и в целевом признаке **churn**.

# %% [markdown]
# Построим графики, чтобы увидеть распределения по признакам:

# %% [markdown]
# Напишем функция для построения графика категориального признака и вывода количественной информации о нем:

# %%
def categorial_plot(data, column):
    sns.set()
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.countplot(x=column, data=data)
    ax.set_title('Распределение по признаку ' + column, size=15)
    plt.ylabel('Количество')
    plt.xlabel(column)
    print(' ')
    print(data[column].value_counts(normalize=True))

# %% [markdown]
# **type**

# %%
sns.set()
fig, ax = plt.subplots(figsize=(3, 4))
sns.countplot(x='type', data=contract)
ax.set_title('Распределение по признаку Type', size=15)
plt.xticks(rotation=45)
plt.ylabel('Количество')
plt.xlabel('Type')
# Out:
# Text(0.5, 0, 'Type')

# %%
contract['type'].value_counts(normalize=True)
# Out:
# Month-to-month    0.550192
# Two year          0.240664
# One year          0.209144
# Name: type, dtype: float64

# %% [markdown]
# **paperless_billing**

# %%
categorial_plot(contract, 'paperless_billing')
# Out:
#
# Yes    0.592219
# No     0.407781
# Name: paperless_billing, dtype: float64

# %% [markdown]
# **payment_method**

# %%
sns.set()
fig, ax = plt.subplots(figsize=(4, 4))
sns.countplot(x='payment_method', data=contract)
ax.set_title('Распределение по признаку Payment Method', size=15)
plt.xticks(rotation=45)
plt.ylabel('Количество')
plt.xlabel('Payment Method')
# Out:
# Text(0.5, 0, 'Payment Method')

# %%
contract['payment_method'].value_counts(normalize=True)
# Out:
# Electronic check             0.335794
# Mailed check                 0.228880
# Bank transfer (automatic)    0.219225
# Credit card (automatic)      0.216101
# Name: payment_method, dtype: float64

# %% [markdown]
# **churn**

# %%
categorial_plot(contract, 'churn')
# Out:
#
# 0    0.73463
# 1    0.26537
# Name: churn, dtype: float64

# %% [markdown]
# **Вывод**

# %% [markdown]
# 1. В качестве основного расчетного периода преобладает "Month-to-month", его используют примерно 55% клиентов, два других расчетного периода используются примерно одинаково (24% и 21%);
# 2. Выставление счета в электронной форме более популярно, его используют около 60% клиентов;
# 3. Наиболее популярна электронная оплата "Electronic check" (33.5%), остальные способы оплаты используются примерно одинаково;
# 4. Отток клиентов достаточно высок и составляет 26.5% от всех клиентов, заключивших договор с оператором связи.

# %% [markdown]
# **Распределение количественных признаков**

# %% [markdown]
# Построим графики распределений численных признаков:

# %% [markdown]
# **monthly_charges**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(contract['monthly_charges'])
plt.title('Распределение по признаку Monthly Charges', size=15)
plt.xlabel('Сумма', size=12)
# Out:
# Text(0.5, 0, 'Сумма')

# %% [markdown]
# **total_charges**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(contract['total_charges'])
plt.title('Распределение по признаку Total Charges', size=15)
plt.xlabel('Сумма', size=12)
# Out:
# Text(0.5, 0, 'Сумма')

# %% [markdown]
# **contract_time**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(contract['contract_time'])
plt.title('Распределение по признаку Contract Time', size=15)
plt.xlabel('Сумма', size=12)
# Out:
# Text(0.5, 0, 'Сумма')

# %%
contract.describe()
# Out:
#        monthly_charges  total_charges        churn  contract_time
# count      7043.000000    7043.000000  7043.000000    7043.000000
# mean         64.761692    2279.798992     0.265370     985.996166
# std          30.090047    2266.730170     0.441561     747.587844
# min          18.250000      18.800000     0.000000       0.000000
# 25%          35.500000     398.550000     0.000000     273.000000
# 50%          70.350000    1394.550000     0.000000     883.000000
# 75%          89.850000    3786.600000     1.000000    1676.000000
# max         118.750000    8684.800000     1.000000    2191.000000

# %% [markdown]
# **Вывод:**

# %% [markdown]
# 1. Признак **MonthlyCharges** - пики присутствуют около 20 и 80 ед, медиана всех значений - 70.35;
# 2. Значения признака **Total Charges** постепенно снижаются от 18.8 до 8684.8 - от клиентов, которые только заключили договор с оператором, до тех, кто уже давно пользуется услугами телеком компании. Медиана - 1394.5;
# 3. Срок продолжительности договора варьируется от 0 месяцев до 71, медиана - 29 месяцев (2.4 года).

# %% [markdown]
# Определим, имеется ли зависимость между признаками, записанными в столбцах датасета:

# %%
axes = pd.plotting.scatter_matrix(contract, figsize = (13, 13))

# %%
contract.corr()
# Out:
#                  monthly_charges  total_charges     churn  contract_time
# monthly_charges         1.000000       0.651182  0.193356       0.247754
# total_charges           0.651182       1.000000 -0.198347       0.826095
# churn                   0.193356      -0.198347  1.000000      -0.352673
# contract_time           0.247754       0.826095 -0.352673       1.000000

# %% [markdown]
# 1. Наибольшая зависимость между признаками **Total Charges** и **Contract Time**, что логично - чем дольше контракт, тем больше сумма итоговых платежей. Учитывая высокую зависимость между данными признаками равную 0.82, а также наибольшую зависимость между целевым признаком и **Contract Time**, предлагается для "облегчения" обучения моделей исключить из данных признак **Total Charges**;
# 2. Также присутствует зависимость между признаками **Monthly Charges** и **Total Chargees**, что также ожидаемо.

# %% [markdown]
# #### Датасет "personal"

# %% [markdown]
# Приведем наименования столбцов датасета к нижнему регистру:

# %%
personal.set_axis(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents'], axis=1, inplace=True)

# %% [markdown]
# Посмотрим на распределение категориальных признаков датасета с персональными данными клиентов:

# %% [markdown]
# **gender**

# %%
categorial_plot(personal, 'gender')
# Out:
#
# Male      0.504756
# Female    0.495244
# Name: gender, dtype: float64

# %% [markdown]
# **senior_citizen**

# %%
categorial_plot(personal, 'senior_citizen')
# Out:
#
# 0    0.837853
# 1    0.162147
# Name: senior_citizen, dtype: float64

# %% [markdown]
# **partner**

# %%
categorial_plot(personal, 'partner')
# Out:
#
# No     0.516967
# Yes    0.483033
# Name: partner, dtype: float64

# %% [markdown]
# **dependents**

# %%
categorial_plot(personal, 'dependents')
# Out:
#
# No     0.700412
# Yes    0.299588
# Name: dependents, dtype: float64

# %% [markdown]
# **Вывод:**

# %% [markdown]
# 1. По полу (**gender**) клиенты компании подразделяются на мужчин и женщин в соотношении 50:50;
# 2. Пенсионеры (**senior_citizen**) составляют всего 16% общей численности клиентов;
# 3. Клиенты, имеющие пару и не имеющие (**partner**), распределились также практически ровно пополам;
# 4. Имеют иждивенцев (**dependents**) 30% численности всех клиентов.

# %% [markdown]
# #### Датасет "internet"

# %% [markdown]
# Приведем наименования столбцов датасета к нижнему регистру:

# %%
internet.set_axis(['customer_id', 'interne_service', 'online_security', 'online_backup', 'device_protection', 
                              'tech_support', 'streaming_tv', 'streaming_movies'], axis=1, inplace=True)

# %% [markdown]
# Посмотрим на распределение категориальных признаков датасета **internet**:

# %% [markdown]
# **interne_service**

# %%
categorial_plot(internet, 'interne_service')
# Out:
#
# Fiber optic    0.561175
# DSL            0.438825
# Name: interne_service, dtype: float64

# %% [markdown]
# **online_security**

# %%
categorial_plot(internet, 'online_security')
# Out:
#
# No     0.63404
# Yes    0.36596
# Name: online_security, dtype: float64

# %% [markdown]
# **online_backup**

# %%
categorial_plot(internet, 'online_backup')
# Out:
#
# No     0.559724
# Yes    0.440276
# Name: online_backup, dtype: float64

# %% [markdown]
# **device_protection**

# %%
categorial_plot(internet, 'device_protection')
# Out:
#
# No     0.560993
# Yes    0.439007
# Name: device_protection, dtype: float64

# %% [markdown]
# **tech_support**

# %%
categorial_plot(internet, 'tech_support')
# Out:
#
# No     0.629509
# Yes    0.370491
# Name: tech_support, dtype: float64

# %% [markdown]
# **streaming_tv**

# %%
categorial_plot(internet, 'streaming_tv')
# Out:
#
# No     0.509335
# Yes    0.490665
# Name: streaming_tv, dtype: float64

# %% [markdown]
# **streaming_movies**

# %%
categorial_plot(internet, 'streaming_movies')
# Out:
#
# No     0.504803
# Yes    0.495197
# Name: streaming_movies, dtype: float64

# %% [markdown]
# **Вывод:**

# %% [markdown]
# 1. Подключение по оптоволокну (**interne_service**) начинает преобладать над DSL и составляет 56%;
# 2. Услугу блокировщик небезопасных сайтов (**online_security**) предпочитают 63.4% всех клиентов;
# 3. Резервное копирование данных в облачное хранилище (**online_backup**) подключили 44% клиентов;
# 4. Услугу антивируса (**device_protection**) используют 43.9% клиентов;
# 5. Оплачивать выделенную тех. поддержку (**tech_support**) согласны 37% клиентов;
# 6. Стриминговое ТВ используют 49% клиентов;
# 7. Сервис просмотра фильмов (**streaming_movies**) подключен 49.5% клиентов.
#
# В целом мы видим, что количество клиентов, пользующихся различными интернет-услугами оператора связи, распределено равномерно и не имеет явных "перекосов" в использовании какой-либо услугой.

# %% [markdown]
# #### Датасет "phone"

# %% [markdown]
# Приведем наименования столбцов датасета к нижнему регистру:

# %%
phone.set_axis(['customer_id', 'multiple_lines'], axis=1, inplace=True)

# %% [markdown]
# И посмотрим на распределение единственного признака:

# %%
categorial_plot(phone, 'multiple_lines')
# Out:
#
# No     0.532935
# Yes    0.467065
# Name: multiple_lines, dtype: float64

# %%
phone['multiple_lines'].count()
# Out:
# 6361

# %% [markdown]
# **Вывод:**

# %% [markdown]
# Услуга подключения аппарата к нескольким линиям (**multiple_lines**) пользуется достаточно высоким спросом. Из 7043 клиентов оператора имеют телефонный аппарат 6361 клиент и из них пользуются услугой 46.7% абонентов.

# %% [markdown]
# ### Вывод по разделу "Исследовательский анализ данных"

# %% [markdown]
# Резюмируем информацию, полученную на втором этапе выполнения проекта:

# %% [markdown]
# 1.	Данные состоят из 4 датасетов:
#
# <li>Датасет <b>contract</b> (информация о договорах клиентов с оператором связи) состоит из 8 столбцов (признаков) и 7043 записей (объектов);</li>
# <li>Датасет <b>personal</b> (информация о персональных данных клиентов) состоит из 5 столбцов (признаков) и 7043 записей (объектов);</li>
# <li>Датасет <b>internet</b> (информация о доступных интернет-услугах оператора связи) состоит из 8 столбцов (признаков) и 5517 записей (объектов);</li>
# <li>Датасет <b>phone</b> (информация об услугах телефонии, используемых клиентом) состоит из 2 столбцов (признаков) и 6361 записи (объекта).</li>
#
# 2.	Пропущенные значения и дубликаты в датасетах при первичном просмотре не обнаружены.
# 3.	Наименования столбцов датасетов приведены к нижнему регистру.
# 4.	Целевой признак определен по значениям столбца **end_date** и записан в столбец **churn**.
# 5.	Данные в столбцах **begin_date** и **end_date** приведены к типу datetime64.
# 6.	Значения в столбце **total_charges** приведены к вещественному типу float64.
# 7.	К датасету **contract** добавлен столбец **contract_time** - рассчитано, сколько дней клиенты пользовались, либо еще пользуются, услугами оператора связи.
# 8.	Рассмотрены распределения категориальных и количественных признаков. В целом, распределение категориальных признаков равномерно и не имеет явных "перекосов" в какую-либо сторону.

# %% [markdown]
# ### План работы

# %% [markdown]
# **Примерный план выполнения работы:**
#
# **<div>1. Исследовательский анализ данных (выполнено)</div>**
#
# **<div>2. Предобработка данных</div>**
# Объединение данных в одну таблицу, рассмотрение вопроса о недостающих, либо излишних данных. Преобразование категориальных признаков в численные, скалирование данных при необходимости. Выделение целевого и учебных признаков, разбивка данных на выборки.
#
# **<div>3. Подбор и обучение моделей</div>**
# Обучение моделей с различными гиперпараметрами и валидация моделей. Тестирование дамми модели.
#
# **<div>4. Проверка данных на тестовой выборке</div>**
# Проверка модели на тестовой выборке. Описание результатов.

# %% [markdown]
# ### Вопросы тимлиду

# %% [markdown]
# 1. В условии задачи указано, что целевой признак: столбец 'EndDate' равен 'No', где 'No' означает, что договор клиента с компанией не закрыт. Тогда можно представить, что основная задача состоит в том, чтобы определить клиентов, которые лояльны компании и услуги, которыми они пользуются. Но это противоречит основной задаче в преамбуле - оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Предполагаю, что в условии ошибка и целевой признак: столбец 'EndDate' должен указывать на дату окончания договора, означающий фактический уход клиента?
#
# 2. Зная дату заключения ('BeginDate') и расторжения ('EndDate') договора можно определить сколько времени клиент пользовался услугами оператора. По табличным данным я так понимаю, что итоговый счет на оплату выставляется пропорционально количеству дней действия договора? Тогда и срок действия договора, вероятно, логичнее рассчитывать в днях?

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Объединение данных в одну таблицу

# %% [markdown]
# Объединим таблицы в одну методом `merge()` по столбцу **customer_id**:

# %%
df_telecom = contract.merge(personal, on='customer_id', how='outer')

# %%
df_telecom = df_telecom.merge(internet, on='customer_id', how='outer')

# %%
df_telecom = df_telecom.merge(phone, on='customer_id', how='outer')

# %%
df_telecom.head(10)
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month               Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year                No
# 2  3668-QPYBK 2019-10-01 2019-12-01  Month-to-month               Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year                No
# 4  9237-HQITU 2019-09-01 2019-11-01  Month-to-month               Yes
# 5  9305-CDSKC 2019-03-01 2019-11-01  Month-to-month               Yes
# 6  1452-KIOVK 2018-04-01 2020-02-01  Month-to-month               Yes
# 7  6713-OKOMC 2019-04-01 2020-02-01  Month-to-month                No
# 8  7892-POOKP 2017-07-01 2019-11-01  Month-to-month               Yes
# 9  6388-TABGU 2014-12-01 2020-02-01        One year                No
#
#               payment_method  monthly_charges  total_charges  churn  \
# 0           Electronic check            29.85          29.85      0
# ...

# %%
df_telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
# customer_id          7043 non-null object
# begin_date           7043 non-null datetime64[ns]
# end_date             7043 non-null datetime64[ns]
# type                 7043 non-null object
# paperless_billing    7043 non-null object
# payment_method       7043 non-null object
# monthly_charges      7043 non-null float64
# total_charges        7043 non-null float64
# churn                7043 non-null int64
# contract_time        7043 non-null int64
# gender               7043 non-null object
# senior_citizen       7043 non-null int64
# partner              7043 non-null object
# dependents           7043 non-null object
# interne_service      5517 non-null object
# online_security      5517 non-null object
# online_backup        5517 non-null object
# device_protection    5517 non-null object
# tech_support         5517 non-null object
# ...

# %% [markdown]
# Напишем функцию для получения информации о количестве пропущенных значений:

# %%
def isna_sum(data):
    isna = data.isna().sum()
    isna_percent = round((100 * data.isna().sum() / len(data)), 2)
    table = pd.concat([isna, isna_percent], axis=1)
    table = table.rename(columns = {0 : 'total_nan', 1 : 'percent'})
    return table

# %%
isna_sum(df_telecom)
# Out:
#                    total_nan  percent
# customer_id                0     0.00
# begin_date                 0     0.00
# end_date                   0     0.00
# type                       0     0.00
# paperless_billing          0     0.00
# payment_method             0     0.00
# monthly_charges            0     0.00
# total_charges              0     0.00
# churn                      0     0.00
# contract_time              0     0.00
# gender                     0     0.00
# senior_citizen             0     0.00
# partner                    0     0.00
# dependents                 0     0.00
# interne_service         1526    21.67
# online_security         1526    21.67
# online_backup           1526    21.67
# device_protection       1526    21.67
# tech_support            1526    21.67
# streaming_tv            1526    21.67
# streaming_movies        1526    21.67
# multiple_lines           682     9.68

# %% [markdown]
# Пропущенные значения составляют до 21.67%, что достаточно много и исключать эти объекты из датасета нежелательно. Поскольку все признаки с пропущенными значениями категориальные - заполним пропуски 'No':

# %%
df_telecom = df_telecom.fillna('No')
#df_telecom.info()

# %% [markdown]
# ### Преобразование категориальных признаков

# %% [markdown]
# Удалим ненужные для обучения модели признаки. Также для облегчения обучения моделей удалим признак **total_charges** (высокая корреляция 0.82 с признаком **сontract_time**):

# %%
df_telecom = df_telecom.drop(['customer_id', 'begin_date', 'end_date', 'total_charges'], axis=1)

# %% [markdown]
# Преобразуем категориальные признаки в численные с помощью техники прямого кодирования OHE (One-Hot Encoding):

# %%
df_telecom_ohe = pd.get_dummies(df_telecom, drop_first=True)

# %%
df_telecom_ohe.sample(5)
# Out:
#       monthly_charges  churn  contract_time  senior_citizen  type_One year  \
# 5327            19.70      0            914               0              0
# 979             54.95      0           1067               0              1
# 588             99.15      0           2191               0              0
# 6031            29.30      0            365               1              0
# 6241            49.15      1             92               0              0
#
#       type_Two year  paperless_billing_Yes  \
# 5327              1                      0
# 979               0                      1
# 588               1                      1
# 6031              0                      1
# 6241              0                      1
#
#       payment_method_Credit card (automatic)  payment_method_Electronic check  \
# 5327                                       0                                0
# 979                                        0                                0
# ...

# %% [markdown]
# ### Разбивка данных на выборки

# %% [markdown]
# Разделим имеющийся датасет на 3 выборки: обучающую (для обучения модели), валидационную (для более качественной проверки обученной модели) и тестовую в соотношении 3:1:1 (60%:20%:20%).

# %% [markdown]
# Для деления на три выборки используем функцию `train_test_split`:

# %%
train, valid = train_test_split(df_telecom_ohe, test_size=0.4, random_state=12345)

# %%
valid, test = train_test_split(valid, test_size=0.5, random_state=12345)

# %% [markdown]
# Проверим результат разделения данных:

# %%
train.shape
# Out:
# (4225, 22)

# %%
valid.shape
# Out:
# (1409, 22)

# %%
test.shape
# Out:
# (1409, 22)

# %% [markdown]
# Запишем "признаки" в переменную `features`, а "цель" в переменную `target`:

# %%
features_train = train.drop('churn', axis=1)
target_train = train['churn']
features_valid = valid.drop('churn', axis=1)
target_valid = valid['churn']
features_test = valid.drop('churn', axis=1)
target_test = valid['churn']

# %%
print(features_train.shape)
print(target_train.shape)
# Out:
# (4225, 21)
# (4225,)

# %%
print(features_valid.shape)
print(target_valid.shape)
# Out:
# (1409, 21)
# (1409,)

# %%
print(features_test.shape)
print(target_test.shape)
# Out:
# (1409, 21)
# (1409,)

# %% [markdown]
# ### Масштабирование признаков

# %%
features_train.head(5)
# Out:
#       monthly_charges  contract_time  senior_citizen  type_One year  \
# 836             71.40           1888               0              1
# 1005            95.85           1614               1              1
# 4220            19.50           1676               0              1
# 6543            54.75           1888               0              1
# 272             24.80             30               0              0
#
#       type_Two year  paperless_billing_Yes  \
# 836               0                      0
# 1005              0                      1
# 4220              0                      0
# 6543              0                      0
# 272               0                      0
#
#       payment_method_Credit card (automatic)  payment_method_Electronic check  \
# 836                                        1                                0
# 1005                                       1                                0
# ...

# %% [markdown]
# Поскольку в данных есть столбцы с численными признаками, значения и разбросы которых значительно различаются (**monthly_charges**, **contract_time**), означает, что данные признаки необходимо масштабировать - привести к одному масштабу.
#
# Масштабирование выполним методом стандартизации данных.

# %%
numeric = ['monthly_charges', 'contract_time']

pd.options.mode.chained_assignment = None
scaler = StandardScaler()
scaler.fit(features_train[numeric])
features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

features_train.head(5)
# Out:
#       monthly_charges  contract_time  senior_citizen  type_One year  \
# 836          0.219283       1.193698               0              1
# 1005         1.028885       0.825429               1              1
# 4220        -1.499261       0.908760               0              1
# 6543        -0.332042       1.193698               0              1
# 272         -1.323764      -1.303542               0              0
#
#       type_Two year  paperless_billing_Yes  \
# 836               0                      0
# 1005              0                      1
# 4220              0                      0
# 6543              0                      0
# 272               0                      0
#
#       payment_method_Credit card (automatic)  payment_method_Electronic check  \
# 836                                        1                                0
# 1005                                       1                                0
# ...

# %% [markdown]
# ### Вывод по разделу "Предобработка данных"

# %% [markdown]
# На третьем этапе выполнения проекта выполнены следующие шаги:
#
# 1. Информация по четырем датасетам объединена в обну таблицу методом `merge()`. Выполнено заполнение пропущенных значений, образовавшихся после объединения датасетов.
#
# 2. Из датасета исключены столбцы с излишней информацией: **customer_id**, **begin_date**, **end_date**.
#
# 3. Все категориальные признаки преобразованы в численные с помощью техники прямого кодирования OHE (One-Hot Encoding).
#
# 4. Выполнено масштабирование численных признаков (**monthly_charges**, **total_charges**, **contract_time**) методом стандартизации данных.
#
# 5. Датасет разделен на 3 выборки trane, valid, test в соотношении 60% : 20% : 20%. "Признаки" записаны в переменную features, а "цель" в переменную target.

# %% [markdown]
# ## Подбор и обучение моделей

# %% [markdown]
# Обучим следующие модели:
# <li>LogisticRegression</li>
# <li>RandomForestClassifier</li>
# <li>DecisionTreeClassifier</li>
# <li>CatBoostClassifier</li>
# <li>XGBClassifier</li>
# <li>LGBMClassifier</li>

# %% [markdown]
# По условию задачи для оценки качества моделей необходимо применять метрику **AUC-ROC** и дополнительную метрику **Accuracy**.
#
# Напишем функцию для расчета метрик, а также построения графика ROC-кривой.
#
# **ROC-кривая** (кривая ошибок) - показывает соотношение доли ложноположительных ответов (FPR) и доли истинно положительных ответов (TPR). Чем график выше, тем больше значение TPR и лучше качество модели.

# %%
def scoring(model):
    print("AUC-ROC:", round(roc_auc_score(target_valid, model.predict_proba(features_valid)[:, 1]), 6))
    print("Accuracy:", round(accuracy_score(target_valid, predicted), 6))
    
    probabilities_valid = model.predict_proba(features_valid)
    probabilities_one_valid = probabilities_valid[:, 1]
    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.ylim([0.0, 1.0])
    plt.xlim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая')
    plt.show()

# %% [markdown]
# Напишем функцию подбора гиперпараметров. Для подбора гиперпараметров воспользуемся инструментом GridSearchCV.

# %%
def grid(model, parameters, features, target):
    
    search = GridSearchCV(model, parameters, n_jobs=-1)
    search.fit(features, target)
    
    print(search.best_params_)

# %% [markdown]
# Сперва проверим данные с применением базовых моделей `LogisticRegression` и `RandomForestClassifier`.

# %% [markdown]
# ### Модель LogisticRegression

# %%
model_lr = LogisticRegression(random_state=12345, class_weight='balanced')

lr_parameters = dict(C=[0.1, 1, 5, 10, 15, 20, 25, 30])

# %%
# %%time
grid(model_lr, lr_parameters, features_train, target_train)
# Out:
# {'C': 0.1}
# CPU times: user 1.49 s, sys: 1.41 s, total: 2.9 s
# Wall time: 2.89 s

# %%
model_lr = LogisticRegression(random_state=12345, class_weight='balanced', C=0.1)

# %%
model_lr.fit(features_train, target_train)
# Out:
# LogisticRegression(C=0.1, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=12345, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicted = model_lr.predict(features_valid)

# %%
scoring(model_lr)
# Out:
# AUC-ROC: 0.849722
# Accuracy: 0.754436

# %% [markdown]
# ### Модель RandomForestClassifier

# %%
model_rfc = RandomForestClassifier(random_state=12345)

rfc_parameters = dict(n_estimators=range(1, 11), 
                      max_depth=range(10, 51, 10))

# %%
# %%time
grid(model_rfc, rfc_parameters, features_train, target_train)
# Out:
# {'max_depth': 10, 'n_estimators': 9}
# CPU times: user 2.97 s, sys: 0 ns, total: 2.97 s
# Wall time: 2.98 s

# %%
model_rfc = RandomForestClassifier(random_state=12345, n_estimators=9, max_depth=10)

# %%
model_rfc.fit(features_train, target_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=10, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=9,
#                        n_jobs=None, oob_score=False, random_state=12345,
#                        verbose=0, warm_start=False)

# %%
predicted = model_rfc.predict(features_valid)

# %%
scoring(model_rfc)
# Out:
# AUC-ROC: 0.843253
# Accuracy: 0.808375

# %% [markdown]
# ### Модель DecisionTreeClassifier

# %%
model_dtc = DecisionTreeClassifier(random_state=12345, class_weight='balanced')

dtc_parameters = dict(max_depth=range(1, 16))

# %%
# %%time
grid(model_dtc, dtc_parameters, features_train, target_train)
# Out:
# {'max_depth': 4}
# CPU times: user 447 ms, sys: 0 ns, total: 447 ms
# Wall time: 447 ms

# %%
model_dtc = DecisionTreeClassifier(random_state=12345, class_weight='balanced', max_depth=4)

# %%
model_dtc.fit(features_train, target_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=12345, splitter='best')

# %%
predicted = model_dtc.predict(features_valid)

# %%
scoring(model_dtc)
# Out:
# AUC-ROC: 0.83341
# Accuracy: 0.749468

# %% [markdown]
# ### Модель CatBoostClassifier

# %%
model_cbc = CatBoostClassifier(random_state=12345,loss_function='Logloss', learning_rate=0.9, verbose=10)

cbc_parameters = dict(iterations=range(50, 101, 50),
                     max_depth=range(2, 7, 2))

# %%
# %%time
grid(model_cbc, cbc_parameters, features_train, target_train)
# Out:
# 0:	learn: 0.4875493	total: 49.3ms	remaining: 2.41s
# 10:	learn: 0.3802803	total: 60.5ms	remaining: 215ms
# 20:	learn: 0.3440640	total: 71.8ms	remaining: 99.2ms
# 30:	learn: 0.3261953	total: 166ms	remaining: 102ms
# 40:	learn: 0.3050100	total: 260ms	remaining: 57.2ms
# 49:	learn: 0.2978185	total: 272ms	remaining: 0us
# 0:	learn: 0.4883183	total: 1.29ms	remaining: 63.2ms
# 10:	learn: 0.3803664	total: 12.4ms	remaining: 44ms
# 20:	learn: 0.3472479	total: 60.6ms	remaining: 83.7ms
# 30:	learn: 0.3184700	total: 161ms	remaining: 98.9ms
# 40:	learn: 0.3042540	total: 336ms	remaining: 73.7ms
# 49:	learn: 0.2907863	total: 359ms	remaining: 0us
# 0:	learn: 0.4772944	total: 1.44ms	remaining: 70.7ms
# 10:	learn: 0.3669908	total: 15.3ms	remaining: 54.1ms
# 20:	learn: 0.3295530	total: 33.9ms	remaining: 46.9ms
# 30:	learn: 0.3144875	total: 123ms	remaining: 75.5ms
# 40:	learn: 0.2923072	total: 216ms	remaining: 47.5ms
# 49:	learn: 0.2767694	total: 227ms	remaining: 0us
# ...

# %%
model_cbc = CatBoostClassifier(random_state=12345,loss_function='Logloss', learning_rate=0.9, verbose=10, iterations=100, max_depth=2)

# %%
model_cbc.fit(features_train, target_train)
# Out:
# 0:	learn: 0.4823297	total: 1.44ms	remaining: 142ms
# 10:	learn: 0.3759974	total: 14.8ms	remaining: 120ms
# 20:	learn: 0.3414711	total: 65.5ms	remaining: 247ms
# 30:	learn: 0.3252622	total: 159ms	remaining: 354ms
# 40:	learn: 0.3083025	total: 254ms	remaining: 366ms
# 50:	learn: 0.2886575	total: 348ms	remaining: 334ms
# 60:	learn: 0.2744591	total: 442ms	remaining: 283ms
# 70:	learn: 0.2688719	total: 541ms	remaining: 221ms
# 80:	learn: 0.2551138	total: 638ms	remaining: 150ms
# 90:	learn: 0.2415590	total: 733ms	remaining: 72.5ms
# 99:	learn: 0.2354276	total: 749ms	remaining: 0us

# %%
predicted = model_cbc.predict(features_valid)

# %%
scoring(model_cbc)
# Out:
# AUC-ROC: 0.924011
# Accuracy: 0.87154

# %% [markdown]
# ### Модель XGBClassifier

# %%
model_xgbc = XGBClassifier(random_state=12345, n_jobs=-1)

xgbc_parameters = dict(n_estimators=range(100, 501, 400))

# %%
# %%time
grid(model_xgbc, xgbc_parameters, features_train, target_train)
# Out:
# {'n_estimators': 500}
# CPU times: user 13.6 s, sys: 79 ms, total: 13.7 s
# Wall time: 13.9 s

# %%
model_xgbc = XGBClassifier(random_state=12345, n_jobs=-1, n_estimators=500)

# %%
model_xgbc.fit(features_train, target_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=12345,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
predicted = model_xgbc.predict(features_valid)

# %%
scoring(model_xgbc)
# Out:
# AUC-ROC: 0.904845
# Accuracy: 0.841022

# %% [markdown]
# ### Модель LGBMClassifier

# %%
model_lgbmc = LGBMClassifier(random_state=12345, n_jobs=-1)

lgbmc_parameters = dict(n_estimators=range(300, 901, 200),
                      learning_rate=[0.01, 0.1, 1],
                      max_depth=range(2, 11, 2))

# %%
# %%time
grid(model_lgbmc, lgbmc_parameters, features_train, target_train)
# Out:
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 900}
# CPU times: user 18min 19s, sys: 12.6 s, total: 18min 32s
# Wall time: 18min 48s

# %%
model_lgbmc = LGBMClassifier(random_state=12345, n_jobs=-1, n_estimators=900,
                           learning_rate=0.1, max_depth=2)

# %%
model_lgbmc.fit(features_train, target_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=2,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=900, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=12345, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
predicted = model_lgbmc.predict(features_valid)

# %%
scoring(model_lgbmc)
# Out:
# AUC-ROC: 0.912232
# Accuracy: 0.852378

# %% [markdown]
# ### Сводная таблица с результатами

# %%
data_model = {'Модель':['LogisticRegression', 'RandomForestClassifier', 'DecisionTreeClassifier', 'CatBoostClassifier', 'XGBClassifier', 'LGBMClassifier'], 
            'Метрика AUC-ROC': [0.849722, 0.843253, 0.83341, 0.924011, 0.904845, 0.912232],
            'Метрика Accuracy': [0.754436, 0.808375, 0.749468, 0.87154, 0.841022, 0.852378],
            'Количество деревьев': ['-', 9, '-', 100, 500, 900],
            'Макс. глубина': ['-', 10, 4, 2, '-', 2]}

# %%
results_tabel = pd.DataFrame(data_model)
results_tabel.sort_values(by='Метрика AUC-ROC', ascending=False)
# Out:
#                    Модель  Метрика AUC-ROC  Метрика Accuracy  \
# 3      CatBoostClassifier         0.924011          0.871540
# 5          LGBMClassifier         0.912232          0.852378
# 4           XGBClassifier         0.904845          0.841022
# 0      LogisticRegression         0.849722          0.754436
# 1  RandomForestClassifier         0.843253          0.808375
# 2  DecisionTreeClassifier         0.833410          0.749468
#
#   Количество деревьев Макс. глубина
# 3                 100             2
# 5                 900             2
# 4                 500             -
# 0                   -             -
# 1                   9            10
# 2                   -             4

# %% [markdown]
# ### Вывод по разделу "Подбор и обучение моделей"

# %% [markdown]
# На четвертом этапе работы выполнено обучение моделей с применением базовых алгоритмов обучения `LogisticRegression`, `RandomForestClassifier`, `DecisionTreeClassifier`, а также различными алгоритмами градиентного бустинга с подбором гиперпараметров: `CatBoostClassifier`, `XGBClassifier`, `LGBMClassifier`.
#
# 1. Все три модели градиентного бустинга показали более точные результаты, чем базовые.
# 3. Модель `CatBoostClassifier` показала наилучший результат AUC-ROC = 0.924011.

# %% [markdown]
# ## Проверка данных на тестовой выборке

# %% [markdown]
# ### Проверка моделей на тестовой выборке

# %% [markdown]
# Напишем функцию для расчета метрик для тестовой выборки:

# %%
def scoring_test(model):
    print("AUC-ROC test:", round(roc_auc_score(target_test, model.predict_proba(features_test)[:, 1]), 6))
    print("Accuracy test:", round(accuracy_score(target_test, predicted), 6))
    
    probabilities_test = model.predict_proba(features_test)
    probabilities_one_test = probabilities_test[:, 1]
    fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)
    plt.figure()
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.ylim([0.0, 1.0])
    plt.xlim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая')
    plt.show()

# %% [markdown]
# А также построим по каждой модели график важности факторов:

# %%
def feature_importance(model):
    features_importances = pd.Series(model.feature_importances_, index=features_train_sum.columns)

    plt.figure(figsize=(12,7))
    features_importances.nlargest(20).plot(kind='barh', color='skyblue')

    plt.title('График важности факторов', size=18, y=1.02)

# %% [markdown]
# Для более качественного обучения моделей перед проверкой на тестовой выборке объединим данные обучающей и тестовой выборок в общую новую обучающую выборку:

# %%
features_train_sum = pd.concat([features_train, features_valid])
target_train_sum = pd.concat([target_train, target_valid])

# %%
features_train_sum.shape
# Out:
# (5634, 21)

# %%
target_train_sum.shape
# Out:
# (5634,)

# %% [markdown]
# **Проверка модели LogisticRegression**

# %%
model_lr.fit(features_train_sum, target_train_sum)
predicted = model_lr.predict(features_test)

# %%
scoring_test(model_lr)
# Out:
# AUC-ROC test: 0.85287
# Accuracy test: 0.755855

# %% [markdown]
# **Проверка модели RandomForestClassifier**

# %%
model_rfc.fit(features_train_sum, target_train_sum)
predicted = model_rfc.predict(features_test)

# %%
scoring_test(model_rfc)
# Out:
# AUC-ROC test: 0.939016
# Accuracy test: 0.857346

# %%
feature_importance(model_rfc)

# %% [markdown]
# **Проверка модели DecisionTreeClassifier**

# %%
model_dtc.fit(features_train_sum, target_train_sum)
predicted = model_dtc.predict(features_test)

# %%
scoring_test(model_dtc)
# Out:
# AUC-ROC test: 0.838647
# Accuracy test: 0.753016

# %%
feature_importance(model_dtc)

# %% [markdown]
# **Проверка модели CatBoostClassifier**

# %%
model_cbc.fit(features_train_sum, target_train_sum)
predicted = model_cbc.predict(features_test)
# Out:
# 0:	learn: 0.4677637	total: 1.94ms	remaining: 192ms
# 10:	learn: 0.3742199	total: 19.2ms	remaining: 155ms
# 20:	learn: 0.3365086	total: 121ms	remaining: 456ms
# 30:	learn: 0.3177971	total: 228ms	remaining: 507ms
# 40:	learn: 0.3040399	total: 331ms	remaining: 476ms
# 50:	learn: 0.2967190	total: 429ms	remaining: 412ms
# 60:	learn: 0.2837531	total: 530ms	remaining: 339ms
# 70:	learn: 0.2737174	total: 710ms	remaining: 290ms
# 80:	learn: 0.2657524	total: 808ms	remaining: 190ms
# 90:	learn: 0.2595731	total: 908ms	remaining: 89.8ms
# 99:	learn: 0.2489537	total: 1s	remaining: 0us

# %%
scoring_test(model_cbc)
# Out:
# AUC-ROC test: 0.947448
# Accuracy test: 0.89851

# %%
feature_importance(model_cbc)

# %% [markdown]
# **Проверка модели XGBClassifier**

# %%
model_xgbc.fit(features_train_sum, target_train_sum)
predicted = model_xgbc.predict(features_test)

# %%
scoring_test(model_xgbc)
# Out:
# AUC-ROC test: 0.956295
# Accuracy test: 0.891412

# %%
feature_importance(model_xgbc)

# %% [markdown]
# **Проверка модели LGBMClassifier**

# %%
model_lgbmc.fit(features_train_sum, target_train_sum)
predicted = model_lgbmc.predict(features_test)

# %%
scoring_test(model_lgbmc)
# Out:
# AUC-ROC test: 0.94576
# Accuracy test: 0.878637

# %%
feature_importance(model_lgbmc)

# %% [markdown]
# ### Сравнение выбранной модели с константной

# %% [markdown]
# Сравним также результат работы выбранной модели с результатом константной `DummyClassifier`:

# %%
dummy_clf = DummyClassifier(strategy="most_frequent", random_state=12345)
dummy_clf.fit(features_train_sum, target_train_sum)
predicted = dummy_clf.predict(features_test)
accuracy = dummy_clf.score(features_test, target_test)
print("AUC-ROC:", round(roc_auc_score(target_test, dummy_clf.predict_proba(features_valid)[:, 1]), 6))
print("Accuracy:", round(accuracy_score(target_test, predicted), 6))
# Out:
# AUC-ROC: 0.5
# Accuracy: 0.728886

# %% [markdown]
# Результаты обученных моделей значительно превосходят результат константной.

# %% [markdown]
# ### Сводная таблица с результатами

# %% [markdown]
# Соберем итоговую таблицу с результатами, полученными на валидационной и тестовой выборках:

# %%
final_data_model = {'Модель':['LogisticRegression', 'RandomForestClassifier', 'DecisionTreeClassifier', 'CatBoostClassifier', 'XGBClassifier', 'LGBMClassifier'], 
            'Метрика AUC-ROC (valid)': [0.849722, 0.843253, 0.83341, 0.924011, 0.904845, 0.912232],
            'Метрика Accuracy (valid)': [0.754436, 0.808375, 0.749468, 0.87154, 0.841022, 0.852378],
            'Метрика AUC-ROC (test)': [0.85287, 0.939016, 0.838647, 0.947448, 0.956295, 0.94576],
            'Метрика Accuracy (test)': [0.755855, 0.857346, 0.753016, 0.89851, 0.891412, 0.878637],        
            'Количество деревьев': ['-', 9, '-', 100, 500, 900],
            'Макс. глубина': ['-', 10, 4, 2, '-', 2]}

# %%
final_results_tabel = pd.DataFrame(final_data_model)
final_results_tabel.sort_values(by='Метрика AUC-ROC (test)', ascending=False)
# Out:
#                    Модель  Метрика AUC-ROC (valid)  Метрика Accuracy (valid)  \
# 4           XGBClassifier                 0.904845                  0.841022
# 3      CatBoostClassifier                 0.924011                  0.871540
# 5          LGBMClassifier                 0.912232                  0.852378
# 1  RandomForestClassifier                 0.843253                  0.808375
# 0      LogisticRegression                 0.849722                  0.754436
# 2  DecisionTreeClassifier                 0.833410                  0.749468
#
#    Метрика AUC-ROC (test)  Метрика Accuracy (test) Количество деревьев  \
# 4                0.956295                 0.891412                 500
# 3                0.947448                 0.898510                 100
# 5                0.945760                 0.878637                 900
# 1                0.939016                 0.857346                   9
# 0                0.852870                 0.755855                   -
# ...

# %% [markdown]
# ### Вывод по разделу "Проверка данных на тестовой выборке"

# %% [markdown]
# На пятом этапе успешно выполнена проверка всех моделей на тестовой выборке - с поставленной задачей в целом справились все модели.
#
# Модели `XGBClassifier`, `LGBMClassifier`, `CatBoostClassifier`, `RandomForestClassifier` показали практически одинаковые результаты на тестовой выборке, наилучший результат предсказан алгоритмом `XGBClassifier`.
#
# С учетом полученных метрик AUC-ROC и Accuracy, а также скорости работы модели, рекомендованы к применению алгоритмы `XGBClassifier` и `CatBoostClassifier`.
